# %% [markdown]
# # Exploring Data
# This notebook is aimed to explore cargo repo data

# %%
import pandas
import matplotlib
import seaborn
import collections
import itertools

import sys
sys.path.append('..')

from helper import load_data , load_repo

# %matplotlib inline

# %%
cargo = load_repo('Cargo')

# %%
cargo_git = cargo[cargo.Repository_URL.notnull()]
cargo_git = cargo_git[cargo_git.Repository_URL.str.contains('github')]
cargo_git = cargo_git.drop_duplicates(subset='Repository_URL')

# %%
packages, dependencies = load_data('Cargo')

# %%
unique_cargo_packages = packages.drop_duplicates(subset='package',keep = 'last')

# %%
unique_cargo_packages.head(10)
# Out:
#              package version                date
# 0              acorn   1.0.0 2014-11-21 01:13:02
# 1                  a   0.0.1 2014-11-21 00:06:54
# 9             acacia   0.1.2 2017-02-26 16:14:51
# 19    abort_on_panic   2.0.0 2017-11-29 21:58:03
# 20        adamantium   0.0.1 2014-11-21 06:48:26
# 21               aio   0.0.1 2015-01-04 21:30:57
# 29      advapi32-sys   0.2.0 2016-02-08 01:05:06
# 49            alfred   4.0.1 2017-11-13 19:46:50
# 62         algebloat   0.0.8 2015-04-17 03:48:15
# 75  algebloat_macros   0.0.8 2015-04-17 03:48:07

# %%
dependencies.head(10)
# Out:
#   package version             target constraint
# 0  acacia   0.0.1           nalgebra     ~0.1.0
# 1  acacia   0.0.1         quickcheck     ~0.1.5
# 2  acacia   0.0.1  quickcheck_macros     ~0.1.5
# 3  acacia   0.0.2          itertools          *
# 4  acacia   0.0.2         quickcheck          *
# 5  acacia   0.0.2           nalgebra          *
# 6  acacia   0.0.3               rand          *
# 7  acacia   0.0.3          itertools          *
# 8  acacia   0.0.4               rand          *
# 9  acacia   0.0.4          itertools          *
