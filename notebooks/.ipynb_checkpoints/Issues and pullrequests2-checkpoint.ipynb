# %%
import pandas
import matplotlib
import requests
import warnings

import sys
sys.path.append('..')

from helper import load_data , load_repo , GIT_API
warnings.filterwarnings('ignore')

# %matplotlib inline

import os
import json
import time

# %%
json_store_dir = '..'+os.sep+'data'+os.sep+'json'

# %%
testrepo = 'https://github.com/rust-lang/cargo'

ISSUE = 'issue'
PULL = 'pull'

time_sleep = 0.1

OPEN = 'open'
CLOSED = 'closed'

# %%
# this function extracts number of open and closed issues of passed repository
def get_open_closed_issues(repo):
    add = repo + '/issues'
    time.sleep(time_sleep)
    req = requests.get(add)
    data = req.text
    
    try:
        open_issues = int(data.split('<svg class="octicon octicon-issue-opened"')[2].split('Open')[0].split('</svg>')[1].strip().replace(",",""))
        closed_issues = int(data.split('<svg class="octicon octicon-check"')[1].split('Closed')[0].split('</svg>')[1].strip().replace(",",""))
    except:
        open_issues = 0
        closed_issues = 0
    
    return open_issues, closed_issues

# %%
#this function fetches comment of issues or pull request and returns a dataframe of comments
def get_comments(repo,issue_id,is_pull_issue):
    df = pandas.DataFrame(columns=["project_name","issue_number","comment_id","user_login","created_at","updated_at","author_assoc"])
    
    repo_parts = repo.split('/')
    repo_full = repo_parts[-2]+'/'+repo_parts[-1]
    print(repo_full)
    
    if is_pull_issue==ISSUE:
        par_folder = json_store_dir+os.sep+'issue_comments'+os.sep+repo_full.replace('/',os.sep)
        json_store_location = par_folder+os.sep+str(issue_id)+'.json'
    elif is_pull_issue==PULL:
        par_folder = json_store_dir+os.sep+'pull_comments'+os.sep+repo_full.replace('/',os.sep)
        json_store_location = par_folder+os.sep+str(issue_id)+'.json'
        
    print(json_store_location)
    if os.path.exists(json_store_location):
        with open(json_store_location) as f:
            comments = json.load(f)
    else:
        issue_comment = 'https://api.github.com/repos/{}/{}/issues/{}/comments?client_id={}&client_secret={}'.format(
                repo.split('/')[3] ,
                repo.split('/')[4] ,
                issue_id,
                GIT_API[5].split(':')[0] , GIT_API[5].split(':')[1])
        print(issue_comment)
        time.sleep(time_sleep)
        req = requests.get(issue_comment)
        print(req.headers['X-RateLimit-Remaining'])
        comments = req.json()
        if not os.path.exists(par_folder):
            os.makedirs(par_folder)
        with open(json_store_location, 'w') as outfile:
            json.dump(comments, outfile)
            
    for comment in comments:
        df = df.append({
            "project_name": repo,
            "issue_number": issue_id,
            "comment_id": comment['id'],
            "user_login": comment['user']['login'],
            "created_at": comment['created_at'],
            "updated_at": comment['updated_at'],
            "author_assoc": comment['author_association'] },ignore_index=True)
    return df

# %%
# this function extracts number of open and closed pull requests of passed repository
def get_open_closed_pulls(repo):
    add = repo + '/pulls'
    time.sleep(time_sleep)
    req = requests.get(add)
    data = req.text
    
    open_pulls = int(data.split('<svg class="octicon octicon-git-pull-request"')[2].split('Open')[0].split('</svg>')[1].strip().replace(",",""))
    closed_pulls = int(data.split('<svg class="octicon octicon-check"')[1].split('Closed')[0].split('</svg>')[1].strip().replace(",",""))
    
    return open_pulls, closed_pulls

# %%
#this function fetches review comment of pull request and returns a dataframe of review comments
def get_pull_comments(repo,pr_id):
    df = pandas.DataFrame(columns=["project_name",
                                   "pr_id",
                                   "pr_review_id",
                                   "comment_id",
                                   "commit_id",
                                   "original_commit_id",
                                   "user_login",
                                   "created_at",
                                   "updated_at",
                                   "author_assoc"])
    
    repo_parts = repo.split('/')
    repo_full = repo_parts[-2]+'/'+repo_parts[-1]
    print(repo_full)
    
    par_folder = json_store_dir+os.sep+'code_review_comments'+os.sep+repo_full.replace('/',os.sep)
    json_store_location = par_folder+os.sep+str(pr_id)+'.json'
        
    if os.path.exists(json_store_location):
        with open(json_store_location) as f:
            comments = json.load(f)
    else:
        pr_comment = 'https://api.github.com/repos/{}/{}/pulls/{}/comments?client_id={}&client_secret={}'.format(
                repo.split('/')[3] ,
                repo.split('/')[4] ,
                pr_id,
                GIT_API[4].split(':')[0] , GIT_API[4].split(':')[1])
        time.sleep(time_sleep)
        req = requests.get(pr_comment)
        print(req.headers['X-RateLimit-Remaining'])
        comments = req.json()
        
        if not os.path.exists(par_folder):
            os.makedirs(par_folder)
        with open(json_store_location, 'w') as outfile:
            json.dump(comments, outfile)
        
        
    for comment in comments:
        df = df.append({
            "project_name": repo,
            "pr_id": pr_id,
            "pr_review_id" : comment['pull_request_review_id'],
            "comment_id": comment['id'],
            "commit_id" : comment['commit_id'],
            "original_commit_id" : comment['original_commit_id'],
            "user_login": comment['user']['login'],
            "created_at": comment['created_at'],
            "updated_at": comment['updated_at'],
            "author_assoc": comment['author_association'] },ignore_index=True)
    return df

# %% [markdown]
# # Dataframes

# %% [markdown]
# # Open/Closed Issues Comments

# %%
def get_issues_comments(repo,is_open_closed,issues_number):
    issue_comments = pandas.DataFrame(columns=["project_name","issue_number","comment_id","user_login","created_at","updated_at","author_assoc"])
    for i in range(1,(issues_number//25)+2):
        issues_page_url = repo + ('/issues?page={}&q=is%3Aissue+is%3A'+is_open_closed).format(i)
        print(issues_page_url)
        time.sleep(time_sleep)
        req = requests.get(issues_page_url)
        data = req.text
        issues = data.split('id="issue_')
        for issue in issues:
            if 'DOCTYPE' in issue:
                continue

            if 'octicon octicon-comment' in issue:
                issue_id = issue.split('"')[0]
                issue_comments = issue_comments.append(get_comments(repo,issue_id,ISSUE),ignore_index=True)
                
    return issue_comments

# %% [markdown]
# # Open/Closed Pull Request Comments

# %%
def get_pulls_comments(repo,is_open_closed,pulls_number):
    pulls_comments = pandas.DataFrame(columns=["project_name","issue_number","comment_id","user_login","created_at","updated_at","author_assoc"])
    pulls_review_comments = pandas.DataFrame(columns=["project_name","pr_id","pr_review_id","comment_id","commit_id","original_commit_id","user_login","created_at","updated_at","author_assoc"])
    for i in range(1,(pulls_number//25)+2):
        pull_page_url = repo + ('/pulls?page={}&q=is%3Apr+is%3A'+is_open_closed).format(i)
        print(pull_page_url)
        time.sleep(time_sleep)
        req = requests.get(pull_page_url)
        data = req.text
        issues = data.split('id="issue_')
        for issue in issues:
            if 'DOCTYPE' in issue:
                continue
            if 'octicon octicon-comment' in issue:
                pr_id = issue.split('"')[0]
                pulls_comments = pulls_comments.append(get_comments(repo,pr_id,PULL),ignore_index=True)
                pulls_review_comments = pulls_review_comments.append(get_pull_comments(repo,pr_id),ignore_index=True)
    return pulls_comments, pulls_review_comments

# %% [markdown]
# # Read selected repos data

# %%
issue_comments = pandas.DataFrame(columns=["project_name","issue_number","comment_id","user_login","created_at","updated_at","author_assoc"])
pulls_comments = pandas.DataFrame(columns=["project_name","issue_number","comment_id","user_login","created_at","updated_at","author_assoc"])
pulls_review_comments = pandas.DataFrame(columns=["project_name","pr_id","pr_review_id","comment_id","commit_id","original_commit_id","user_login","created_at","updated_at","author_assoc"])

# %%
selected_repos = pandas.read_csv('../data/selected_repos.csv')
for repo in selected_repos.target_url.unique():
    # extracting number of issues and prs for proposed repo
    open_issue , closed_issue = get_open_closed_issues(repo)
    open_pr , closed_pr = get_open_closed_pulls(repo)
    
    issue_comments = issue_comments.append(get_issues_comments(repo,OPEN,open_issue),ignore_index=True)
    issue_comments.to_csv('../data/issue_comments.csv.gz',compression='gzip')
    issue_comments = issue_comments.append(get_issues_comments(repo,CLOSED,closed_issue),ignore_index=True)
    issue_comments.to_csv('../data/issue_comments.csv.gz',compression='gzip')
    
    pc, prc = get_pulls_comments(repo,OPEN,open_pr)
    pulls_comments = pulls_comments.append(pc,ignore_index=True)
    pulls_review_comments = pulls_review_comments.append(prc,ignore_index=True)
    pulls_comments.to_csv('../data/pulls_comments.csv.gz',compression='gzip')
    pulls_review_comments.to_csv('../data/pulls_review_comments.csv.gz',compression='gzip')
    
    pc, prc = get_pulls_comments(repo,CLOSED,closed_pr)
    pulls_comments = pulls_comments.append(pc,ignore_index=True)
    pulls_review_comments = pulls_review_comments.append(prc,ignore_index=True)
    pulls_comments.to_csv('../data/pulls_comments.csv.gz',compression='gzip')
    pulls_review_comments.to_csv('../data/pulls_review_comments.csv.gz',compression='gzip')
# Out:
# https://github.com/serde-rs/serde/issues?page=1&q=is%3Aissue+is%3Aopen
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1410.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1407.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1403.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1402.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1374.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1346.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1343.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1325.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1307.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1276.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1238.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1232.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1218.json
# https://github.com/serde-rs/serde/issues?page=2&q=is%3Aissue+is%3Aopen
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1195.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1183.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1147.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1146.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1128.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1118.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1117.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1098.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1061.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1059.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1042.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1041.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1033.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1025.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1021.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1019.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\979.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\953.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\952.json
# https://github.com/serde-rs/serde/issues?page=3&q=is%3Aissue+is%3Aopen
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\947.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\939.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\919.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\912.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\902.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\897.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\881.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\870.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\850.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\812.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\760.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\748.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\745.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\723.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\690.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\644.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\642.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\637.json
# https://github.com/serde-rs/serde/issues?page=4&q=is%3Aissue+is%3Aopen
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\610.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\595.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\586.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\553.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\531.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\497.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\493.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\481.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\450.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\368.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\286.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\271.json
# https://github.com/serde-rs/serde/issues?page=1&q=is%3Aissue+is%3Aclosed
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1415.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1414.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1413.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1412.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1409.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1408.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1406.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1405.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1404.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1401.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1400.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1398.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1397.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1395.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1389.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\1388.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\
json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\206.json
# https://github.com/serde-rs/serde/issues?page=28&q=is%3Aissue+is%3Aclosed
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\203.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\202.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\200.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\197.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\196.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\195.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\194.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\192.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\188.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\187.json
# serde-rs/serde
# ..\data\json\issue_comments\serde-rs\serde\186.json
# serde-rs/serde
# ...
# ..\data\json\issue_comments\sfackler\rust-openssl\532.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\529.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\528.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\527.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\526.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\523.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\522.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\521.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\520.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\517.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\516.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\514.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\509.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\501.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\500.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\499.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\495.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\491.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\489.json
# https://github.com/sfackler/rust-openssl/issues?page=9&q=is%3Aissue+is%3Aclosed
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\480.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\477.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\466.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\465.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\463.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\462.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\460.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\459.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\457.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\455.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\454.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\453.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\452.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\451.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\449.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\448.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\447.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\445.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\442.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\441.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\438.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\435.json
# https://github.com/sfackler/rust-openssl/issues?page=10&q=is%3Aissue+is%3Aclosed
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\434.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\430.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\422.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\418.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\417.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\415.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\414.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\413.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\409.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\407.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\406.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\405.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\401.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\400.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\397.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\396.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\395.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\394.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\392.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\384.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\383.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\382.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\378.json
# https://github.com/sfackler/rust-openssl/issues?page=11&q=is%3Aissue+is%3Aclosed
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\375.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\370.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\369.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\368.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\366.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\363.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\362.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\357.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\354.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\351.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\338.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\335.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\333.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\332.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\331.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\327.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\326.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\325.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\323.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\321.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\316.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\314.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\313.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\311.json
# https://github.com/sfackler/rust-openssl/issues?page=12&q=is%3Aissue+is%3Aclosed
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\310.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\308.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\305.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\304.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\303.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\302.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\301.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\298.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\295.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\293.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\292.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\291.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\281.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\278.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\274.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\271.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\269.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\264.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\260.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\258.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\257.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\255.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\254.json
# https://github.com/sfackler/rust-openssl/issues?page=13&q=is%3Aissue+is%3Aclosed
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\252.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\250.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\249.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\248.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\245.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\241.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\237.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\235.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\234.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\230.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\228.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\224.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\220.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\216.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\215.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\212.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\209.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\208.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\206.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\205.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\204.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\203.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\197.json
# sfackler/rust-openssl
# ..\data\json\issue_comments\sfackler\rust-openssl\192.json
# https://github.com/sfackler/rust-openssl/issues?page=14&q=is%3Aissue+is%3Aclosed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-69bf7a47f860> in <module>()
#       7     issue_comments = issue_comments.append(get_issues_comments(repo,OPEN,open_issue),ignore_index=True)
#       8     issue_comments.to_csv('../data/issue_comments.csv.gz',compression='gzip')
# ----> 9     issue_comments = issue_comments.append(get_issues_comments(repo,CLOSED,closed_issue),ignore_index=True)
#      10     issue_comments.to_csv('../data/issue_comments.csv.gz',compression='gzip')
#      11
#
# <ipython-input-39-4201ca613349> in get_issues_comments(repo, is_open_closed, issues_number)
#       5         print(issues_page_url)
#       6         time.sleep(time_sleep)
# ----> 7         req = requests.get(issues_page_url)
#       8         data = req.text
#       9         issues = data.split('id="issue_')
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:
